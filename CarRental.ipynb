# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayush04H/Machine_Leaarning2/blob/main/CarRental.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Import Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # **Import Dataset**

# %%
dataset=pd.read_csv('CarRentalData - Copy.csv')
dataset.head()
# Out:
#    fuelType  rating  renterTripsTaken  reviewCount location.city  \
# 0  ELECTRIC    5.00                13           12       Seattle
# 1  ELECTRIC    5.00                 2            1       Tijeras
# 2    HYBRID    4.92                28           24   Albuquerque
# 3  GASOLINE    5.00                21           20   Albuquerque
# 4  GASOLINE    5.00                 3            1   Albuquerque
#
#   location.country  location.latitude  location.longitude location.state  \
# 0               US          47.449107         -122.308841             WA
# 1               US          35.111060         -106.276551             NM
# 2               US          35.127163         -106.566681             NM
# 3               US          35.149726         -106.711425             NM
# 4               US          35.208659         -106.601008             NM
#
#    owner.id  rate.daily vehicle.make vehicle.model  vehicle.year vehicle.type
# 0  12847615         135        Tesla       Model X          2019          suv
# 1  15621242         190        Tesla       Model X          2018          suv
# 2  10199256          35       Toyota         Prius          2012          car
# 3   9365496          75         Ford       Mustang          2018          car
# 4   3553565          47     Chrysler       Sebring          2010          car
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_0, *['rating'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_1, *['renterTripsTaken'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_2, *['reviewCount'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_3, *['location.latitude'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(_df_4, *['fuelType'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(_df_5, *['location.city'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(_df_6, *['location.state'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(_df_7, *['vehicle.make'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plots(df, colname_pairs, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * 6 * figscale, 6 * figscale))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha, ax=ax)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(_df_8, *[[['rating', 'renterTripsTaken'], ['renterTripsTaken', 'reviewCount'], ['reviewCount', 'location.latitude'], ['location.latitude', 'location.longitude']]], **{})
# chart
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_9, *['rating'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_10, *['renterTripsTaken'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_11, *['reviewCount'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_12, *['location.latitude'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def heatmap(df, x_colname, y_colname, figscale=1, mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=(8 * figscale, 8 * figscale))
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(_df_13, *['fuelType', 'location.city'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def heatmap(df, x_colname, y_colname, figscale=1, mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=(8 * figscale, 8 * figscale))
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(_df_14, *['location.city', 'location.state'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def heatmap(df, x_colname, y_colname, figscale=1, mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=(8 * figscale, 8 * figscale))
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(_df_15, *['location.state', 'vehicle.make'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def heatmap(df, x_colname, y_colname, figscale=1, mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=(8 * figscale, 8 * figscale))
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(_df_16, *['vehicle.make', 'vehicle.model'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_17, *['rating', 'fuelType'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_18, *['rating', 'location.city'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_19, *['rating', 'location.state'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_20, *['rating', 'vehicle.make'], **{'inner': 'stick'})
# chart

# %% [markdown]
# **To Check for the null values**

# %%
dataset.isnull().sum()
# Out:
# fuelType               75
# rating                501
# renterTripsTaken        0
# reviewCount             0
# location.city           0
# location.country        0
# location.latitude       0
# location.longitude      0
# location.state          0
# owner.id                0
# rate.daily              0
# vehicle.make            0
# vehicle.model           0
# vehicle.year            0
# vehicle.type            0
# dtype: int64

# %% [markdown]
# # **No Of Rows And Columns**

# %%
dataset.shape
# Out:
# (5851, 15)

# %% [markdown]
# # **Description of Data**

# %%
dataset.describe()
# Out:
#             rating  renterTripsTaken  reviewCount  location.country  \
# count  5851.000000       5851.000000  5851.000000            5851.0
# mean      4.920179         33.477354    28.454794               1.0
# std       0.187516         41.898954    35.136113               0.0
# min       1.000000          0.000000     0.000000               1.0
# 25%       4.900000          5.000000     4.000000               1.0
# 50%       5.000000         18.000000    16.000000               1.0
# 75%       5.000000         46.000000    39.000000               1.0
# max       5.000000        395.000000   321.000000               1.0
#
#        location.latitude  location.longitude      owner.id   rate.daily  \
# count        5851.000000         5851.000000  5.851000e+03  5851.000000
# mean           35.582889          -99.632773  6.034830e+06    93.691506
# std             6.431408           20.391476  4.646022e+06    96.080920
# min            21.272565         -158.165693  5.105000e+03    20.000000
# 25%            30.453623         -117.158285  1.917451e+06    45.000000
# 50%            35.554502          -95.673319  4.968749e+06    69.000000
# 75%            39.996864          -81.538631  9.657496e+06   110.000000
# max            64.893610          -68.823637  1.581088e+07  1500.000000
#
#        vehicle.year  vehicle.type
# count   5851.000000   5851.000000
# mean    2015.340113      0.507776
# std        4.050813      0.798759
# min     1955.000000      0.000000
# 25%     2014.000000      0.000000
# 50%     2016.000000      0.000000
# 75%     2018.000000      1.000000
# max     2020.000000      4.000000

# %% [markdown]
# **Dealing with the Null data**

# %%
dataset['fuelType'].fillna(method ='ffill',  inplace = True)
dataset['rating'].fillna(method ='ffill',  inplace = True)
dataset.isnull().sum()
# Out:
# fuelType              0
# rating                0
# renterTripsTaken      0
# reviewCount           0
# location.city         0
# location.country      0
# location.latitude     0
# location.longitude    0
# location.state        0
# owner.id              0
# rate.daily            0
# vehicle.make          0
# vehicle.model         0
# vehicle.year          0
# vehicle.type          0
# dtype: int64

# %% [markdown]
# # Encoding IndeDependent Variable

# %% [markdown]
# # **Encoding The Dependent Variable**

# %%
dataset['vehicle.type'].value_counts()
# Out:
# car        3659
# suv        1714
# minivan     232
# truck       191
# van          55
# Name: vehicle.type, dtype: int64

# %%
dataset.replace({'vehicle.type':{'car':0,'suv':1,'minivan':2,'truck':3,'van':4},'location.country':{'US':1}},inplace=True)
dataset.head()
# Out:
#    fuelType  rating  renterTripsTaken  reviewCount location.city  \
# 0  ELECTRIC    5.00                13           12       Seattle
# 1  ELECTRIC    5.00                 2            1       Tijeras
# 2    HYBRID    4.92                28           24   Albuquerque
# 3  GASOLINE    5.00                21           20   Albuquerque
# 4  GASOLINE    5.00                 3            1   Albuquerque
#
#    location.country  location.latitude  location.longitude location.state  \
# 0                 1          47.449107         -122.308841             WA
# 1                 1          35.111060         -106.276551             NM
# 2                 1          35.127163         -106.566681             NM
# 3                 1          35.149726         -106.711425             NM
# 4                 1          35.208659         -106.601008             NM
#
#    owner.id  rate.daily vehicle.make vehicle.model  vehicle.year  vehicle.type
# 0  12847615         135        Tesla       Model X          2019             1
# 1  15621242         190        Tesla       Model X          2018             1
# 2  10199256          35       Toyota         Prius          2012             0
# 3   9365496          75         Ford       Mustang          2018             0
# 4   3553565          47     Chrysler       Sebring          2010             0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_21, *['rating'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_22, *['renterTripsTaken'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_23, *['reviewCount'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_24, *['location.latitude'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(_df_25, *['fuelType'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(_df_26, *['location.city'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(_df_27, *['location.state'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(_df_28, *['vehicle.make'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plots(df, colname_pairs, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * 6 * figscale, 6 * figscale))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha, ax=ax)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(_df_29, *[[['rating', 'renterTripsTaken'], ['renterTripsTaken', 'reviewCount'], ['reviewCount', 'location.latitude'], ['location.latitude', 'location.longitude']]], **{})
# chart
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_30, *['location.country', 'rating', 'fuelType'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_31, *['location.country', 'rating', 'location.city'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_32, *['location.country', 'rating', 'location.state'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_33, *['location.country', 'rating', 'vehicle.make'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_34, *['rating'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_35, *['renterTripsTaken'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_36, *['reviewCount'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_37, *['location.latitude'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def heatmap(df, x_colname, y_colname, figscale=1, mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=(8 * figscale, 8 * figscale))
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(_df_38, *['fuelType', 'location.city'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def heatmap(df, x_colname, y_colname, figscale=1, mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=(8 * figscale, 8 * figscale))
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(_df_39, *['location.city', 'location.state'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def heatmap(df, x_colname, y_colname, figscale=1, mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=(8 * figscale, 8 * figscale))
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(_df_40, *['location.state', 'vehicle.make'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def heatmap(df, x_colname, y_colname, figscale=1, mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=(8 * figscale, 8 * figscale))
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(_df_41, *['vehicle.make', 'vehicle.model'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_42, *['rating', 'fuelType'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_43, *['rating', 'location.city'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_44, *['rating', 'location.state'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_45, *['rating', 'vehicle.make'], **{'inner': 'stick'})
# chart

# %%
dataset['vehicle.type'].value_counts()
# Out:
# 0    3659
# 1    1714
# 2     232
# 3     191
# 4      55
# Name: vehicle.type, dtype: int64

# %%
x=dataset.drop(columns='vehicle.type',axis=1)
y=dataset['vehicle.type']

# %%
print(x)
# Out:
#       fuelType  rating  renterTripsTaken  reviewCount location.city  \
# 0     ELECTRIC    5.00                13           12       Seattle
# 1     ELECTRIC    5.00                 2            1       Tijeras
# 2       HYBRID    4.92                28           24   Albuquerque
# 3     GASOLINE    5.00                21           20   Albuquerque
# 4     GASOLINE    5.00                 3            1   Albuquerque
# ...        ...     ...               ...          ...           ...
# 5846  GASOLINE    5.00                32           27      Honolulu
# 5847    HYBRID    5.00                17           16          Aiea
# 5848  GASOLINE    4.94                18           17        Kailua
# 5849  GASOLINE    4.94                 1            0       Waipahu
# 5850  GASOLINE    5.00                16           14        Kailua
#
#       location.country  location.latitude  location.longitude location.state  \
# 0                    1          47.449107         -122.308841             WA
# 1                    1          35.111060         -106.276551             NM
# 2                    1          35.127163         -106.566681             NM
# 3                    1          35.149726         -106.711425             NM
# 4                    1          35.208659         -106.601008             NM
# ...                ...                ...                 ...            ...
# 5846                 1          21.292950         -157.836856             HI
# 5847                 1          21.375507         -157.914919             HI
# 5848                 1          21.378719         -157.727816             HI
# 5849                 1          21.376105         -158.020237             HI
# 5850                 1          21.378040         -157.730000             HI
#
#       owner.id  rate.daily vehicle.make vehicle.model  vehicle.year
# 0     12847615         135        Tesla       Model X          2019
# 1     15621242         190        Tesla       Model X          2018
# 2     10199256          35       Toyota         Prius          2012
# 3      9365496          75         Ford       Mustang          2018
# 4      3553565          47     Chrysler       Sebring          2010
# ...        ...         ...          ...           ...           ...
# 5846   9794111          33    Chevrolet         Cruze          2017
# 5847   2754690          49        Lexus       HS 250h          2010
# 5848  11313508          35        smart        fortwo          2013
# 5849   4209883          77          GMC        Savana          2015
# 5850  11313508          35        smart        fortwo          2013
#
# [5851 rows x 14 columns]

# %%
print(y)
# Out:
# 0       1
# 1       1
# 2       0
# 3       0
# 4       0
#        ..
# 5846    0
# 5847    0
# 5848    0
# 5849    4
# 5850    0
# Name: vehicle.type, Length: 5851, dtype: int64

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct=ColumnTransformer(transformers=[('encoder',OneHotEncoder(),[0,4,8,11,12])],remainder='passthrough')
x=ct.fit_transform(x)

# %%
print(x)
# Out:
#   (0, 1)	1.0
#   (0, 804)	1.0
#   (0, 1018)	1.0
#   (0, 1070)	1.0
#   (0, 1387)	1.0
#   (0, 1601)	5.0
#   (0, 1602)	13.0
#   (0, 1603)	12.0
#   (0, 1604)	1.0
#   (0, 1605)	47.449107
#   (0, 1606)	-122.308841
#   (0, 1607)	12847615.0
#   (0, 1608)	135.0
#   (0, 1609)	2019.0
#   (1, 1)	1.0
#   (1, 878)	1.0
#   (1, 1006)	1.0
#   (1, 1070)	1.0
#   (1, 1387)	1.0
#   (1, 1601)	5.0
#   (1, 1602)	2.0
#   (1, 1603)	1.0
#   (1, 1604)	1.0
#   (1, 1605)	35.11106
#   (1, 1606)	-106.276551
#   :	:
#   (5849, 986)	1.0
#   (5849, 1036)	1.0
#   (5849, 1482)	1.0
#   (5849, 1601)	4.94
#   (5849, 1602)	1.0
#   (5849, 1604)	1.0
#   (5849, 1605)	21.376105
#   (5849, 1606)	-158.020237
#   (5849, 1607)	4209883.0
#   (5849, 1608)	77.0
#   (5849, 1609)	2015.0
#   (5850, 2)	1.0
#   (5850, 434)	1.0
#   (5850, 986)	1.0
#   (5850, 1074)	1.0
#   (5850, 1593)	1.0
#   (5850, 1601)	5.0
#   (5850, 1602)	16.0
#   (5850, 1603)	14.0
#   (5850, 1604)	1.0
#   (5850, 1605)	21.37804
#   (5850, 1606)	-157.73
#   (5850, 1607)	11313508.0
#   (5850, 1608)	35.0
#   (5850, 1609)	2013.0

# %% [markdown]
# # **Split Test and Train data**

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %% [markdown]
# # **Feature scaling**

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler(with_mean=False)
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
x=sc.transform(x)

# %% [markdown]
# # **Training The Model**

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = 'linear', random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %% [markdown]
# # **Predicting of The Test Set**

# %%
y_pred=classifier.predict(X_test)

# %% [markdown]
# # **Confusion Metrics and accuracy score**

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
cm=confusion_matrix(y_test,y_pred)
print(cm)
acc=accuracy_score(y_test, y_pred)
print('The Accuracy for the Model will be :',acc*100,'%')
# Out:
# [[723  10   0   0   0]
#  [ 12 338   0   0   0]
#  [  2   0  39   0   0]
#  [  2   2   0  33   0]
#  [  0   0   0   0  10]]
# The Accuracy for the Model will be : 97.60888129803587 %

# %% [markdown]
# # **Making A Predictive System**

# %%
n=int(input("Enter the Number of Data Upto which u want to check the data in X_test"))
for a in range(0,n+1):
  inp=X_test[a]
  prediction=classifier.predict(inp)
  print(prediction)
  if(prediction==0):
    print("The Vehicle Rented is a Car as it is mapped with value ",prediction)
  elif(prediction==1):
    print("The Vehicle Rented is a SUV as it is mapped with value ",prediction)
  elif(prediction==2):
    print("The Vehicle Rented is a minivan as it is mapped with value ",prediction)
  elif(prediction==3):
    print("The Vehicle Rented is a truck as it is mapped with value ",prediction)
  elif(prediction==4):
    print("The Vehicle Rented is a van as it is mapped with value ",prediction)
  else:
    print('Unable to Predict')
# Out:
# Enter the Number of Data Upto which u want to check the data in X_test200
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [2]
# The Vehicle Rented is a minivan as it is mapped with value  [2]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [3]
# The Vehicle Rented is a truck as it is mapped with value  [3]
# [3]
# The Vehicle Rented is a truck as it is mapped with value  [3]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [4]
# The Vehicle Rented is a van as it is mapped with value  [4]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [2]
# The Vehicle Rented is a minivan as it is mapped with value  [2]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [4]
# The Vehicle Rented is a van as it is mapped with value  [4]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [2]
# The Vehicle Rented is a minivan as it is mapped with value  [2]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [2]
# The Vehicle Rented is a minivan as it is mapped with value  [2]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [2]
# The Vehicle Rented is a minivan as it is mapped with value  [2]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [2]
# The Vehicle Rented is a minivan as it is mapped with value  [2]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [2]
# The Vehicle Rented is a minivan as it is mapped with value  [2]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [3]
# The Vehicle Rented is a truck as it is mapped with value  [3]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [2]
# The Vehicle Rented is a minivan as it is mapped with value  [2]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [3]
# The Vehicle Rented is a truck as it is mapped with value  [3]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
